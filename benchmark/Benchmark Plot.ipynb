# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("benchmark_times.txt",sep ="\t", header=None)
data.columns = ["# of Nodes", "std::map", "Unbalanced Tree", "Balanced Tree"]

# %%
data
# Out:
#      # of Nodes  std::map  Unbalanced Tree  Balanced Tree
# 0           100    0.0095           0.0078         0.0065
# 1           110    0.0102           0.0086         0.0029
# 2           120    0.0042           0.0035         0.0032
# 3           130    0.0048           0.0039         0.0033
# 4           140    0.0045           0.0039         0.0027
# ..          ...       ...              ...            ...
# 986        9960    0.4413           0.4698         0.3932
# 987        9970    0.4498           0.4894         0.3894
# 988        9980    0.4525           0.4830         0.3787
# 989        9990    0.4511           0.4774         0.3794
# 990       10000    0.4522           0.4786         0.3824
#
# [991 rows x 4 columns]

# %%
fig = plt.figure(figsize=(12,8))
plt.ylabel("Time (microsecond)")
plt.xlabel("Number of Nodes")

ax = plt.subplot(111)

ax.plot(data['# of Nodes'], data['std::map'], label = 'std::map')
ax.plot(data['# of Nodes'], data['Unbalanced Tree'], label = 'Unbalanced Tree')
ax.plot(data['# of Nodes'], data['Balanced Tree'], label = 'Balanced Tree')

plt.title("Benchmark Results")
ax.legend()

plt.savefig("Benchmark_results.png")
# Out:
# /home/john/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   """
